# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_hang_up_figure

# %%
file_root_dir = r"E:\Project\MyJupyters\研究计算\data\\"
fig = plt.figure(figsize=(16,14)) 
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,r"D5.3-Exit.xlsx","0.6H")

plt.subplot(221)
folder_name = "矩形立坑計算"
plot_hang_up_figure(folder_name,"D5.3-0.6H Rectangle.csv")

plt.subplots_adjust(wspace =0.3, hspace =0)
save_figure(file_root_dir,"W5.3 compare.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9d15454e14aa> in <module>()
#       2 fig = plt.figure(figsize=(16,14))
#       3 plt.subplot(222)
# ----> 4 plot_exit_hang_up_figure(file_root_dir,r"D5.3-Exit.xlsx","0.6H")
#       5
#       6 plt.subplot(221)
#
# E:\Project\MyJupyters\研究计算\WellDataPlot\plotdata.py in plot_exit_hang_up_figure(root_dir, filename, sheet_name, D, H, min_coh)
#     119
#     120 def plot_exit_hang_up_figure(root_dir, filename, sheet_name, D=None, H=None, min_coh=None):
# --> 121     d1, d2, d3 = readDataFromXlsx(filename, sheet_name, root_dir)
#     122     d1 = np.array(d1)
#     123     d2 = np.array(d2)
#
# E:\Project\MyJupyters\研究计算\WellDataPlot\ReadData.py in readDataFromXlsx(file_name, sheet_name, XLSX_PATH)
#      11     hangup2_datas = []
#      12
# ---> 13     wb = load_workbook(XLSX_PATH+ file_name)
#      14     try:
#      15         sheet = wb[ sheet_name ]
#
# E:\Program Files\Anaconda\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, guess_types, keep_links)
#     172
#     173     """
# --> 174     archive = _validate_archive(filename)
#     175
#     176     src = archive.read(ARC_CONTENT_TYPES)
#
# E:\Program Files\Anaconda\lib\site-packages\openpyxl\reader\excel.py in _validate_archive(filename)
#     119
#     120     try:
# --> 121         archive = ZipFile(filename, 'r', ZIP_DEFLATED)
#     122     except BadZipfile:
#     123         f = repair_central_directory(filename, is_file_like)
#
# E:\Program Files\Anaconda\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\Project\\MyJupyters\\研究计算\\\\D5.3-Exit.xlsx'

# %%
file_root_dir = r"E:\Jupyter\研究计算\data\\"
fig = plt.figure(figsize=(16,14)) 
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,r"D7.0-Exit.xlsx","0.6H")

plt.subplot(221)
folder_name = "矩形立坑計算"
plot_hang_up_figure(folder_name,"D7.0-0.6H Rectangle.csv")
plt.subplots_adjust(wspace =0.3, hspace =0)
save_figure(file_root_dir,"W7.0 compare.png")

# %%
file_root_dir = r"E:\Jupyter\研究计算\data\\"
fig = plt.figure(figsize=(16,14)) 
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,r"D8.9-Exit.xlsx","0.6H")

plt.subplot(221)
folder_name = "矩形立坑計算"
plot_hang_up_figure(folder_name,"D8.9-0.6H Rectangle.csv")
plt.subplots_adjust(wspace =0.3, hspace =0)
save_figure(file_root_dir,"W8.9 compare.png")
