# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_hang_up_figure

fig_size = (10,6)
file_root_dir = "./円形立坑計算"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 直径6ｍ　0.2H

# %%
plt.figure(figsize=fig_size) 
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.2H",yrange=[0,20]

# %% [markdown]
# # 直径6ｍ　0.4H

# %%
plt.figure(figsize=fig_size) 
plot_exit_hang_up_figure(file_root_dir,"D6.xlsx","0.4H")

# %% [markdown]
# # 直径6ｍ　0.6H

# %%
plt.figure(figsize=fig_size) 
plot_exit_hang_up_figure(file_root_dir,"D6.xlsx","0.6H")

# %% [markdown]
# # 直径6ｍ　0.8H

# %%
plt.figure(figsize=fig_size) 
plot_exit_hang_up_figure(file_root_dir,"D6.xlsx","0.8H")
