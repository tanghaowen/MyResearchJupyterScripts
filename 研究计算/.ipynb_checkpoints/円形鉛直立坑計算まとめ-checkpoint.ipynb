# %%
import matplotlib.pyplot as plt 
import numpy as np
from WellDataPlot.plotdata import plot_hang_up_figure
from WellDataPlot.plotdata import save_figure

# %% [markdown]
# # 基本情報設定

# %%
# 基本情報設定
folder_name = "円形立坑計算"

def plot_6_02H():
    plot_hang_up_figure(folder_name,"D6-0.2H Circle.csv",6,0.2,3.5e4)
def plot_6_04H():
    plot_hang_up_figure(folder_name,"D6-0.4H Circle.csv",6,0.4)
def plot_6_06H():
    plot_hang_up_figure(folder_name,"D6-0.6H Circle.csv",6,0.6)
def plot_6_08H():
    plot_hang_up_figure(folder_name,"D6-0.8H Circle.csv",6,0.8)
    
def plot_8_02H():
    plot_hang_up_figure(folder_name,"D8-0.2H Circle.csv",8,0.2)
def plot_8_04H():
    plot_hang_up_figure(folder_name,"D8-0.4H Circle.csv",8,0.4)
def plot_8_06H():
    plot_hang_up_figure(folder_name,"D8-0.6H Circle.csv",8,0.6)
def plot_8_08H():
    plot_hang_up_figure(folder_name,"D8-0.8H Circle.csv",8,0.8)
    
    
def plot_9_02H():
    plot_hang_up_figure(folder_name,"D9-0.2H Circle.csv",9,0.2,7.0e4)
def plot_9_04H():
    plot_hang_up_figure(folder_name,"D9-0.4H Circle.csv",9,0.4,6.93e4)
def plot_9_06H():
    plot_hang_up_figure(folder_name,"D9-0.6H Circle.csv",9,0.6)
def plot_9_08H():
    plot_hang_up_figure(folder_name,"D9-0.8H Circle.csv",9,0.8)
    
def plot_10_02H():
    plot_hang_up_figure(folder_name,"D10-0.2H Circle.csv",10,0.2)
def plot_10_04H():
    plot_hang_up_figure(folder_name,"D10-0.4H Circle.csv",10,0.4)
def plot_10_06H():
    plot_hang_up_figure(folder_name,"D10-0.6H Circle.csv",10,0.6)
def plot_10_08H():
    plot_hang_up_figure(folder_name,"D10-0.8H Circle.csv",10,0.8)
    
def plot_big_ball():
    plot_hang_up_figure(folder_name,"big_ball_D8.csv",8,1.0,"off")

# %% [markdown]
# # 直径$D=6m$のまとめ

# %%
plt.figure(figsize=(22,14))
plt.suptitle('The Compare Of Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_6_02H()
plt.subplot(222)
plot_6_04H()
plt.subplot(223)
plot_6_06H()
plt.subplot(224)
plot_6_08H()

plt.subplots_adjust(hspace=0.5)

save_figure(folder_name,"D6_compare.png")

# %% [markdown]
# # 直径$D=8m$のまとめ

# %%
plt.figure(figsize=(22,14))
plt.suptitle('The Compare Of Well $D=8m$', fontsize=40,y=1)

plt.subplot(221)
plot_8_02H()
plt.subplot(222)
plot_8_04H()
plt.subplot(223)
plot_8_06H()
plt.subplot(224)
plot_8_08H()

plt.subplots_adjust(hspace=0.5)

save_figure(folder_name,"D8_compare.png")

# %% [markdown]
# # 直径$D=9m$のまとめ

# %%
plt.figure(figsize=(22,14))
plt.suptitle('The Compare Of Well $D=9m$', fontsize=40,y=1)

plt.subplot(221)
plot_9_02H()
plt.subplot(222)
plot_9_04H()
plt.subplot(223)
plot_9_06H()
plt.subplot(224)
plot_9_08H()

plt.subplots_adjust(hspace=0.5)

save_figure(folder_name,"D9_compare.png")

# %% [markdown]
# # 直径$D=10m$のまとめ

# %%
plt.figure(figsize=(22,14))
plt.suptitle('The Compare Of Well $D=10m$', fontsize=40,y=1)

plt.subplot(221)
plot_10_02H()
plt.subplot(222)
plot_10_04H()
plt.subplot(223)
plot_10_06H()
plt.subplot(224)
plot_10_08H()

plt.subplots_adjust(hspace=0.5)

save_figure(folder_name,"D10_compare.png")
