# %%
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib

from WellDataPlot.plotdata import plot_experiment_resault

plot_experiment_resault("実験/23.4mm石実験データ.csv","$23.4\ mm$ Rock Experiment")

fp = matplotlib.font_manager.FontProperties("Yu Mincho",size=20)
plt.title("石実験データ",fontproperties=fp)
plt.show()
# Out:
# [ 80.  90. 100.]

# %%
import matplotlib.font_manager
import pandas as pd
fonts = matplotlib.font_manager.findSystemFonts()

l = []
for f in fonts:
    try:
        font =matplotlib.font_manager.FontProperties(fname=f)
        #print(font.get_family())
        l.append((f, font.get_name(), font.get_family(), font.get_weight()))
    except:
        pass
df = pd.DataFrame(l, columns=['path', 'name', 'family', 'weight'])
df
# Out:
#                                                   path  \
# 0                          C:\WINDOWS\Fonts\方正悠黑简体.TTF
# 1                          C:\WINDOWS\Fonts\BRLNSB.TTF
# 2                          C:\WINDOWS\Fonts\comici.ttf
# 3                        c:\windows\fonts\baskvill.ttf
# 4                        c:\windows\fonts\itcblkad.ttf
# 5                        c:\windows\fonts\freescpt.ttf
# 6                        C:\WINDOWS\Fonts\cambriab.ttf
# 7                        C:\WINDOWS\Fonts\MSUIGHUB.TTF
# 8    c:\program files (x86)\adobe\acrobat dc\resour...
# 9                        c:\windows\fonts\trebucit.ttf
# 10          C:\WINDOWS\Fonts\DejaVuSansMono-Bold_0.ttf
# 11                        C:\WINDOWS\Fonts\BOOKOSB.TTF
# 12                        c:\windows\fonts\calisti.ttf
# 13              c:\windows\fonts\amemuchigothic-02.ttf
# 14                       c:\windows\fonts\gili____.ttf
# 15                         c:\windows\fonts\corbel.ttf
# ...

# %%
import matplotlib
font_pro1 = matplotlib.font_manager.FontProperties("Yu Mincho")
plt.plot([123,12,3,4])
plt.title("このすば",size=100,fontproperties=font_pro1)
# Out:
# Text(0.5,1,'このすば')
