# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_hang_up_figure
matplotlib.axes.mtransforms
fig_size = (17,13)
single_fig_size = (7.5,6.5)
file_root_dir = "./矩形立坑計算"

# %% [markdown]
# # 辺長 5.3m

# %%
filename = "L5.3.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.2H",title="$L=5.3m\ H_0=0.2H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_5.3m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.4H",title="$L=5.3m\ H_0=0.4H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_5.3m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.6H",title="$L=5.3m\ H_0=0.6H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_5.3m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.8H",title="$L=5.3m\ H_0=0.8H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_5.3m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.2H",title="$L=5.3m\ H_0=0.2H$",anotate_position=(9e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.4H",title="$L=5.3m\ H_0=0.4H$",anotate_position=(9e4,4))
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.6H",title="$L=5.3m\ H_0=0.6H$",anotate_position=(9e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"L5.3.xlsx","0.8H",title="$L=5.3m\ H_0=0.8H$",anotate_position=(9e4,4),min_coh=3.82e4)

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L5.3m_compare.png")

# %% [markdown]
# # 辺長 7.0m

# %%
filename = "L7.0.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.2H",title="$L=7.0m\ H_0=0.2H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.0m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.4H",title="$L=7.0m\ H_0=0.4H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.0m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.6H",title="$L=7.0m\ H_0=0.6H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.0m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.8H",title="$L=7.0m\ H_0=0.8H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.0m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.2H",title="$L=7.0m\ H_0=0.2H$",anotate_position=(9e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.4H",title="$L=7.0m\ H_0=0.4H$",anotate_position=(9e4,4))
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.6H",title="$L=7.0m\ H_0=0.6H$",anotate_position=(9e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"L7.0.xlsx","0.8H",title="$L=7.0m\ H_0=0.8H$",anotate_position=(9e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L7.0m_compare.png")

# %% [markdown]
# # 辺長 7.9m

# %%
filename = "L7.9.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.2H",title="$L=7.9m\ H_0=0.2H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.9m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.4H",title="$L=7.9m\ H_0=0.4H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.9m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.6H",title="$L=7.9m\ H_0=0.6H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.9m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.8H",title="$L=7.9m\ H_0=0.8H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_7.9m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.2H",title="$L=7.9m\ H_0=0.2H$",anotate_position=(9e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.4H",title="$L=7.9m\ H_0=0.4H$",anotate_position=(9e4,4))
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.6H",title="$L=7.9m\ H_0=0.6H$",anotate_position=(9e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"L7.9.xlsx","0.8H",title="$L=7.9m\ H_0=0.8H$",anotate_position=(9e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L7.9m_compare.png")

# %% [markdown]
# # 辺長 8.9m

# %%
filename = "L8.9.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.2H",title="$L=8.9m\ H_0=0.2H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_8.9m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.4H",title="$L=8.9m\ H_0=0.4H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_8.9m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.6H",title="$L=8.9m\ H_0=0.6H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_8.9m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.8H",title="$L=8.9m\ H_0=0.8H$",anotate_position=(9e4,4))
save_figure(file_root_dir,"Rectangle_8.9m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.2H",title="$L=8.9m\ H_0=0.2H$",anotate_position=(10e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.4H",title="$L=8.9m\ H_0=0.4H$",anotate_position=(10e4,4))
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.6H",title="$L=8.9m\ H_0=0.6H$",anotate_position=(10e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"L8.9.xlsx","0.8H",title="$L=8.9m\ H_0=0.8H$",anotate_position=(10e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L8.9m_compare.png")
