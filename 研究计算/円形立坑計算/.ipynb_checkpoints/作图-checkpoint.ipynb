# %%
import matplotlib.pyplot as plt 
import numpy as np
from WellDataPlot.plotdata import plot_hang_up_figure

# %%
plt.figure(figsize=(22,14))
plt.subplot(221)
plot_hang_up_figure("D6-0.8H Circle.csv",6,0.8)
plt.subplot(222)
plot_hang_up_figure("D6-0.6H Circle.csv",6,0.6)
plt.subplot(223)
plot_hang_up_figure("D6-0.4H Circle.csv",6,0.4)
plt.subplot(224)
plot_hang_up_figure("D6-0.2H Circle.csv",6,0.2)
plt.subplots_adjust(hspace=0.5)
plt.savefig('D6_all.png', transparent=False, dpi=80, bbox_inches="tight")
