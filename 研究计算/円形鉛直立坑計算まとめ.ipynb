# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_hang_up_figure
matplotlib.axes.mtransforms
fig_size = (17,13)
file_root_dir = "./円形立坑計算"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 直径6ｍ　0.2H 0.4H 0.6H 0.8H

# %%
plt.figure(figsize=fig_size)
plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.2H",title="D6 0.2H")
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.4H",title="D6 0.4H")
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.6H",title="D6 0.6H")
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.8H",title="D6 0.8H")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D6_compare.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-1d9af52b8993> in <module>()
#       3
#       4 plt.subplot(221)
# ----> 5 plot_hang_up_figure(file_root_dir,"D6.xlsx","0.2H",title="D6 0.2H")
#       6 plt.subplot(222)
#       7 plot_hang_up_figure(file_root_dir,"D6.xlsx","0.4H",title="D6 0.4H")
#
# E:\Project\MyJupyters\研究计算\WellDataPlot\plotdata.py in plot_hang_up_figure(root_dir, filename, sheet_name, min_coh, xrange, yrange, title, titlesize, hangeup_text_position, anotate_position)
#     105
#     106 def plot_hang_up_figure(root_dir, filename, sheet_name, min_coh=None ,xrange=[0,15e4],yrange=[0,10],title=None,titlesize=30,hangeup_text_position=(8e4,6),anotate_position=(5e4,4)):
# --> 107     boundary_line_mus, boundary_line_cohs = plot_exit_hang_up_figure(root_dir, filename, sheet_name,xrange=xrange,yrange=yrange,title=title,titlesize=titlesize,hangeup_text_position=hangeup_text_position)
#     108
#     109     # 计算界限粘着力并绘制直线和Minium Cohesion的标注
#
# E:\Project\MyJupyters\研究计算\WellDataPlot\plotdata.py in plot_exit_hang_up_figure(root_dir, filename, sheet_name, xrange, yrange, title, titlesize, hangeup_text_position)
#      61     ax = plt.gca()
#      62
# ---> 63     d1, d2, d3 = readDataFromXlsx(filename, sheet_name, root_dir)
#      64     d1 = np.array(d1)
#      65     d2 = np.array(d2)
#
# E:\Project\MyJupyters\研究计算\WellDataPlot\ReadData.py in readDataFromXlsx(file_name, sheet_name, XLSX_PATH)
#      11     hangup2_datas = []
#      12     if XLSX_PATH[-1] != "\\": XLSX_PATH = XLSX_PATH + "\\"
# ---> 13     wb = load_workbook(XLSX_PATH+ file_name)
#      14     try:
#      15         sheet = wb[ sheet_name ]
#
# E:\Program Files\Anaconda\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, guess_types, keep_links)
#     172
#     173     """
# --> 174     archive = _validate_archive(filename)
#     175
#     176     src = archive.read(ARC_CONTENT_TYPES)
#
# E:\Program Files\Anaconda\lib\site-packages\openpyxl\reader\excel.py in _validate_archive(filename)
#     119
#     120     try:
# --> 121         archive = ZipFile(filename, 'r', ZIP_DEFLATED)
#     122     except BadZipfile:
#     123         f = repair_central_directory(filename, is_file_like)
#
# E:\Program Files\Anaconda\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: './矩形立坑計算\\D6.xlsx'

# %% [markdown]
# # 直径8ｍ　0.2H 0.4H 0.6H 0.8H

# %%
plt.figure(figsize=fig_size)
plt.suptitle('The Compare Of Circle Well $D=8m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.2H",title="D8 0.2H",anotate_position=(8e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.4H",title="D8 0.4H",anotate_position=(8e4,4),min_coh=5.22e4)
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.6H",title="D8 0.6H",anotate_position=(8e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.8H",title="D8 0.8H",anotate_position=(8e4,4),min_coh=4.20e4)

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D8_compare.png")

# %% [markdown]
# # 直径9ｍ　0.2H 0.4H 0.6H 0.8H

# %%
plt.figure(figsize=fig_size)
plt.suptitle('The Compare Of Circle Well $D=9m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.2H",title="D9 0.2H",anotate_position=(10e4,4),min_coh=7.00e4)
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.4H",title="D9 0.4H",anotate_position=(10e4,4),min_coh=6.93e4)
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.6H",title="D9 0.6H",anotate_position=(10e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.8H",title="D9 0.8H",anotate_position=(10e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D9_compare.png")

# %% [markdown]
# # 直径10ｍ　0.2H 0.4H 0.6H 0.8H

# %%
plt.figure(figsize=fig_size)
plt.suptitle('The Compare Of Circle Well $D=10m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.2H",title="D10 0.2H",anotate_position=(10e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.4H",title="D10 0.4H",anotate_position=(10e4,4),min_coh=8.50e4)
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.6H",title="D10 0.6H",anotate_position=(10e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.8H",title="D10 0.8H",anotate_position=(10e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D10_compare.png")

# %%
file_root_dir = "./円形立坑計算"
plt.figure(figsize=(16,5))
plt.subplot(121)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.6H",anotate_position=(10e4,4),title="D=6m $H_o=0.6H$")

file_root_dir = "./矩形立坑計算"
plt.subplot(122)
plot_hang_up_figure(file_root_dir,"W5.3.xlsx","0.6H",anotate_position=(10e4,4),title="L=5.3m $H_o=0.6H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"../compare_circleD10_rectW5.3.png")
