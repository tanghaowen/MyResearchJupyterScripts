# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_hang_up_figure
matplotlib.axes.mtransforms
fig_size = (17,13)
single_fig_size = (7.5,6.5)
file_root_dir = "./円形立坑計算"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 直径6m

# %%
filename = "D6.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.2H",title="$D=6.0m\ H_0=0.2H$")
save_figure(file_root_dir,"Circle_6.0m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.4H",title="$D=6.0m\ H_0=0.4H$")
save_figure(file_root_dir,"Circle_6.0m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.6H",title="$D=6.0m\ H_0=0.6H$")
save_figure(file_root_dir,"Circle_6.0m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.8H",title="$D=6.0m\ H_0=0.8H$")
save_figure(file_root_dir,"Circle_6.0m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.2H",title="$D=6\ H_0=0.2H$")
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.4H",title="$D=6\ H_0=0.4H$")
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.6H",title="$D=6\ H_0=0.6H$")
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.8H",title="$D=6\ H_0=0.8H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D6_compare.png")

# %% [markdown]
# # 直径8ｍ　0.2H 0.4H 0.6H 0.8H

# %%
filename = "D8.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.2H",title="$D=8.0m\ H_0=0.2H$",anotate_position=(8e4,4))
save_figure(file_root_dir,"Circle_8.0m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.4H",title="$D=8.0m\ H_0=0.4H$",anotate_position=(8e4,4),min_coh=5.22e4)
save_figure(file_root_dir,"Circle_8.0m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.6H",title="$D=8.0m\ H_0=0.6H$",anotate_position=(8e4,4))
save_figure(file_root_dir,"Circle_8.0m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.8H",title="$D=8.0m\ H_0=0.8H$",anotate_position=(8e4,4),min_coh=4.20e4)
save_figure(file_root_dir,"Circle_8.0m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=8m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.2H",title="D8 0.2H",anotate_position=(8e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.4H",title="D8 0.4H",anotate_position=(8e4,4),min_coh=5.22e4)
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.6H",title="D8 0.6H",anotate_position=(8e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D8.xlsx","0.8H",title="D8 0.8H",anotate_position=(8e4,4),min_coh=4.20e4)

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D8_compare.png")

# %% [markdown]
# # 直径9ｍ　0.2H 0.4H 0.6H 0.8H

# %%
filename = "D9.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.2H",title="$D=9.0m\ H_0=0.2H$",anotate_position=(10e4,4),min_coh=7.00e4)
save_figure(file_root_dir,"Circle_9.0m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.4H",title="$D=9.0m\ H_0=0.4H$",anotate_position=(10e4,4),min_coh=6.93e4)
save_figure(file_root_dir,"Circle_9.0m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.6H",title="$D=9.0m\ H_0=0.6H$",anotate_position=(10e4,4))
save_figure(file_root_dir,"Circle_9.0m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.8H",title="$D=9.0m\ H_0=0.8H$",anotate_position=(10e4,4))
save_figure(file_root_dir,"Circle_9.0m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=9m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.2H",title="D9 0.2H",anotate_position=(10e4,4),min_coh=7.00e4)
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.4H",title="D9 0.4H",anotate_position=(10e4,4),min_coh=6.93e4)
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.6H",title="D9 0.6H",anotate_position=(10e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D9.xlsx","0.8H",title="D9 0.8H",anotate_position=(10e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D9_compare.png")

# %% [markdown]
# # 直径10ｍ　0.2H 0.4H 0.6H 0.8H

# %%
filename = "D10.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.2H",title="$D=10.0m\ H_0=0.2H$",anotate_position=(10e4,4))
save_figure(file_root_dir,"Circle_10.0m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.4H",title="$D=10.0m\ H_0=0.4H$",anotate_position=(10e4,4),min_coh=8.50e4)
save_figure(file_root_dir,"Circle_10.0m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.6H",title="$D=10.0m\ H_0=0.6H$",anotate_position=(10e4,4))
save_figure(file_root_dir,"Circle_10.0m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_hang_up_figure(file_root_dir,filename,"0.8H",title="$D=10.0m\ H_0=0.8H$",anotate_position=(10e4,4))
save_figure(file_root_dir,"Circle_10.0m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=10m$', fontsize=40,y=1)

plt.subplot(221)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.2H",title="D10 0.2H",anotate_position=(10e4,4))
plt.subplot(222)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.4H",title="D10 0.4H",anotate_position=(10e4,4),min_coh=8.50e4)
plt.subplot(223)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.6H",title="D10 0.6H",anotate_position=(10e4,4))
plt.subplot(224)
plot_hang_up_figure(file_root_dir,"D10.xlsx","0.8H",title="D10 0.8H",anotate_position=(10e4,4))

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"D10_compare.png")

# %%
file_root_dir = "./円形立坑計算"
plt.figure(figsize=(16,5))
plt.subplot(121)
plot_hang_up_figure(file_root_dir,"D6.xlsx","0.6H",anotate_position=(10e4,4),title="D=6m $H_o=0.6H$")

file_root_dir = "./矩形立坑計算"
plt.subplot(122)
plot_hang_up_figure(file_root_dir,"W5.3.xlsx","0.6H",anotate_position=(10e4,4),title="L=5.3m $H_o=0.6H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"../compare_circleD10_rectW5.3.png")
