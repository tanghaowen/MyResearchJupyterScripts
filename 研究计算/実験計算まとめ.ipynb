# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_exit_hang_up_figure
matplotlib.axes.mtransforms
fig_size = (17,13)
single_fig_size = (7.5,6.5)
file_root_dir = "./実験計算"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filename = "大理石.xlsx"

fig = plt.figure(figsize=single_fig_size)
plt.title("Reactangle Sharft L=0.071m Marble",fontsize=24,pad=40)
plot_exit_hang_up_figure(file_root_dir,filename,"矩形0.071m Gap0.0",title="$L=5.3m\ H_0=0.2H$",xrange=[-1,1e4],yrange=[0,1])
save_figure(file_root_dir,"Reactangle Sharft L=0.071m Marble.png")
#plt.close(fig)
# Out:
# 745.0
# (0.0, 0.15, 0.25)
# (6850.0, 1850.0, 0.0)

# %%
filename = "大理石.xlsx"

fig = plt.figure(figsize=single_fig_size)
plt.title("Reactangle Sharft L=0.080m Marble",fontsize=24,pad=40)
plot_exit_hang_up_figure(file_root_dir,filename,"矩形0.08m Gap0.0",title="$L=5.3m\ H_0=0.2H$",xrange=[-1,1e4],yrange=[0,1])
save_figure(file_root_dir,"Reactangle Sharft L=0.080m Marble.png")
#plt.close(fig)
# Out:
# 974.375
# (0.0, 0.15, 0.25, 0.5)
# (8750.0, 1250.0, 925.0, 0.0)

# %%
filename = "大理石.xlsx"

fig = plt.figure(figsize=single_fig_size)
plt.title("Reactangle Sharft L=0.089m Marble",fontsize=24,pad=40)
plot_exit_hang_up_figure(file_root_dir,filename,"矩形0.089m Gap0.0",title="$L=5.3m\ H_0=0.2H$",xrange=[-1,1e4],yrange=[0,1])
save_figure(file_root_dir,"Reactangle Sharft L=0.089m Marble.png")
#plt.close(fig)
# Out:
# 1493.75
# (0.0, 0.15, 0.25, 0.5, 1.0)
# (6250.0, 2000.0, 1750.0, 1250.0, 0.0)

# %% [markdown]
#  # Circle

# %%
filename = "大理石.xlsx"

fig = plt.figure(figsize=single_fig_size)
plt.title("Circle Sharft D=0.071m Marble",fontsize=24,pad=40)
plot_exit_hang_up_figure(file_root_dir,filename,"円形0.071m　Gap0.0",title="$L=5.3m\ H_0=0.2H$",xrange=[-1,1e4],yrange=[0,1])
save_figure(file_root_dir,"Circle Sharft D=0.071m Marble.png")
#plt.close(fig)
# Out:
# 557.5
# (0.0, 0.15, 0.25, 0.5, 1.0)
# (5600.0, 1100.0, 0.0, 0.0, 0.0)
