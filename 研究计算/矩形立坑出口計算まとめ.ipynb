# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib
from WellDataPlot.plotdata import plot_exit_hang_up_figure,save_figure,plot_exit_hang_up_figure
matplotlib.axes.mtransforms
fig_size = (17,13)
single_fig_size = (7.5,6.5)
file_root_dir = "./矩形立坑出口計算"

# %% [markdown]
# # 辺長 5.3m

# %%
filename = "L5.3.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.2H",title="$L=5.3m\ H_0=0.2H$")
save_figure(file_root_dir,"Rectangle_Exit_5.3m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.4H",title="$L=5.3m\ H_0=0.4H$")
save_figure(file_root_dir,"Rectangle_Exit_5.3m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.6H",title="$L=5.3m\ H_0=0.6H$")
save_figure(file_root_dir,"Rectangle_Exit_5.3m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.8H",title="$L=5.3m\ H_0=0.8H$")
save_figure(file_root_dir,"Rectangle_Exit_5.3m_0.8H.png")
plt.close(fig)
# Out:
# 53200.0
# (0.0, 0.5, 1.0, 1.2, 1.25, 1.5)
# (70400.0, 41250.0, 34750.0, 22500.0, 0.0, 0.0)
# 58537.5
# (0.0, 0.5, 1.0, 1.25, 1.5, 2.0, 3.0, 4.0)
# (66400.0, 43750.0, 36000.0, 26250.0, 0.0, 0.0, 0.0, 0.0)
# 72156.25
# (0.0, 0.5, 1.0, 1.25, 1.5, 2.0, 3.0, 4.0)
# (63750.0, 51500.0, 48750.0, 48750.0, 0.0, 0.0, 0.0, 0.0)
# 71493.75
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0, 3.0, 4.0)
# (69100.0, 57500.0, 53125.0, 27500.0, 0.0, 0.0, 0.0, 0.0)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.2H",title="$L=5.3m\ H_0=0.2H$")
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.4H",title="$L=5.3m\ H_0=0.4H$")
plt.subplot(223)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.6H",title="$L=5.3m\ H_0=0.6H$")
plt.subplot(224)
plot_exit_hang_up_figure(file_root_dir,"L5.3.xlsx","0.8H",title="$L=5.3m\ H_0=0.8H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L5.3m_compare.png")
# Out:
# 53200.0
# (0.0, 0.5, 1.0, 1.2, 1.25, 1.5)
# (70400.0, 41250.0, 34750.0, 22500.0, 0.0, 0.0)
# 58537.5
# (0.0, 0.5, 1.0, 1.25, 1.5, 2.0, 3.0, 4.0)
# (66400.0, 43750.0, 36000.0, 26250.0, 0.0, 0.0, 0.0, 0.0)
# 72156.25
# (0.0, 0.5, 1.0, 1.25, 1.5, 2.0, 3.0, 4.0)
# (63750.0, 51500.0, 48750.0, 48750.0, 0.0, 0.0, 0.0, 0.0)
# 71493.75
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0, 3.0, 4.0)
# (69100.0, 57500.0, 53125.0, 27500.0, 0.0, 0.0, 0.0, 0.0)

# %% [markdown]
# # 辺長 7.0m

# %%
filename = "L7.0.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.2H",title="$L=7.0m\ H_0=0.2H$")
save_figure(file_root_dir,"Rectangle_Exit_7.0m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.4H",title="$L=7.0m\ H_0=0.4H$")
save_figure(file_root_dir,"Rectangle_Exit_7.0m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.6H",title="$L=7.0m\ H_0=0.6H$")
save_figure(file_root_dir,"Rectangle_Exit_7.0m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.8H",title="$L=7.0m\ H_0=0.8H$")
save_figure(file_root_dir,"Rectangle_Exit_7.0m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.2H",title="$L=7.0m\ H_0=0.2H$")
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.4H",title="$L=7.0m\ H_0=0.4H$")
plt.subplot(223)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.6H",title="$L=7.0m\ H_0=0.6H$")
plt.subplot(224)
plot_exit_hang_up_figure(file_root_dir,"L7.0.xlsx","0.8H",title="$L=7.0m\ H_0=0.8H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L7.0m_compare.png")
# Out:
# 151562.5
# (0.0, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0)
# (117500.0, 57500.0, 47500.0, 50500.0, 59250.0, 0.0, 0.0)
# 103075.0
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0, 3.0, 4.0)
# (91000.0, 57500.0, 51500.0, 51000.0, 52000.0, 0.0, 0.0, 0.0)
# 84875.0
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0, 4.0)
# (90500.0, 73750.0, 72500.0, 0.0, 0.0, 0.0, 0.0)
# 138187.5
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0, 3.0, 4.0)
# (97500.0, 75000.0, 78750.0, 75000.0, 75000.0, 0.0, 0.0, 0.0)

# %% [markdown]
# # 辺長 7.9m

# %%
filename = "L7.9.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.2H",title="$L=7.9m\ H_0=0.2H$")
save_figure(file_root_dir,"Rectangle_Exit_7.9m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.4H",title="$L=7.9m\ H_0=0.4H$")
save_figure(file_root_dir,"Rectangle_Exit_7.9m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.6H",title="$L=7.9m\ H_0=0.6H$")
save_figure(file_root_dir,"Rectangle_Exit_7.9m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.8H",title="$L=7.9m\ H_0=0.8H$")
save_figure(file_root_dir,"Rectangle_Exit_7.9m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.2H",title="$L=7.9m\ H_0=0.2H$")
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.4H",title="$L=7.9m\ H_0=0.4H$")
plt.subplot(223)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.6H",title="$L=7.9m\ H_0=0.6H$")
plt.subplot(224)
plot_exit_hang_up_figure(file_root_dir,"L7.9.xlsx","0.8H",title="$L=7.9m\ H_0=0.8H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L7.9m_compare.png")
# Out:
# 90375.0
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0, 3.0, 4.0)
# (147500.0, 63750.0, 53750.0, 11250.0, 0.0, 0.0, 0.0, 0.0)
# 157687.5
# (0.0, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0)
# (112500.0, 62500.0, 56250.0, 56000.0, 56250.0, 0.0, 0.0)
# 123500.0
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0)
# (105000.0, 97500.0, 85000.0, 75000.0, 0.0, 0.0)
# 109625.0
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0)
# (119000.0, 95000.0, 92500.0, 0.0, 0.0, 0.0)

# %% [markdown]
# # 辺長 8.9m

# %%
filename = "L8.9.xlsx"

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.2H",title="$L=8.9m\ H_0=0.2H$")
save_figure(file_root_dir,"Rectangle_Exit_8.9m_0.2H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.4H",title="$L=8.9m\ H_0=0.4H$")
save_figure(file_root_dir,"Rectangle_Exit_8.9m_0.4H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.6H",title="$L=8.9m\ H_0=0.6H$")
save_figure(file_root_dir,"Rectangle_Exit_8.9m_0.6H.png")
plt.close(fig)

fig = plt.figure(figsize=single_fig_size)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.8H",title="$L=8.9m\ H_0=0.8H$")
save_figure(file_root_dir,"Rectangle_Exit_8.9m_0.8H.png")
plt.close(fig)

# %%
plt.figure(figsize=fig_size)
#plt.suptitle('The Compare Of Circle Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.2H",title="$L=8.9m\ H_0=0.2H$")
plt.subplot(222)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.4H",title="$L=8.9m\ H_0=0.4H$")
plt.subplot(223)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.6H",title="$L=8.9m\ H_0=0.6H$")
plt.subplot(224)
plot_exit_hang_up_figure(file_root_dir,"L8.9.xlsx","0.8H",title="$L=8.9m\ H_0=0.8H$")

plt.subplots_adjust(hspace=0.4,wspace=0.3)
save_figure(file_root_dir,"L8.9m_compare.png")
# Out:
# 135187.5
# (0.0, 0.5, 1.0, 1.2, 2.0)
# (162500.0, 77500.0, 61250.0, 68750.0, 0.0)
# 88125.0
# (0.0, 0.5, 1.0)
# (145000.0, 72500.0, 62500.0)
# 148437.5
# (0.0, 0.5, 1.0, 1.5, 2.0)
# (123750.0, 102500.0, 90000.0, 42500.0, 0.0)
# 137125.0
# (0.0, 0.5, 1.0, 1.2, 1.5, 2.0)
# (135500.0, 105000.0, 107500.0, 52500.0, 0.0, 0.0)
