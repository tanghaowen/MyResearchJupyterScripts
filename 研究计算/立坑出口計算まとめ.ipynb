# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt 
import numpy as np
from WellDataPlot.plotdata import plot_exit_hang_up_figure
from WellDataPlot.plotdata import save_figure
import matplotlib
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 基本情報設定

# %%
# データのあるフォルダの名前を指定する
folder_name = "立坑出口計算"

def plot_53_02H():
    plot_hang_up_figure(folder_name,"D5.3 0.2H.csv",5.3,0.2)
def plot_53_04H():
    plot_hang_up_figure(folder_name,"D5.3 0.4H.csv",5.3,0.4)
def plot_53_06H():
    plot_hang_up_figure(folder_name,"D5.3 0.6H.csv",5.3,0.6,"off")
def plot_53_08H():
    return plot_hang_up_figure(folder_name,"D5.3 0.8H.csv",5.3,0.8,"off")
def plot_7_02H():
    plot_hang_up_figure(folder_name,"D7 0.2H.csv",7,0.2,0.57e5)
def plot_7_04H():
    plot_hang_up_figure(folder_name,"D7 0.4H.csv",7,0.4)
def plot_7_06H():
    plot_hang_up_figure(folder_name,"D7 0.6H.csv",7,0.6,"off")
def plot_7_08H():
    plot_hang_up_figure(folder_name,"D7 0.8H.csv",7,0.8,"off")
def plot_79_02H():
    plot_hang_up_figure(folder_name,"D7.9 0.2H.csv",7.9,0.2)
def plot_79_04H():
    plot_hang_up_figure(folder_name,"D7.9 0.4H.csv",7.9,0.4)
def plot_79_06H():
    plot_hang_up_figure(folder_name,"D7.9 0.6H.csv",7.9,0.6)
def plot_79_08H():
    plot_hang_up_figure(folder_name,"D7.9 0.8H.csv",7.9,0.8)

# %% [markdown]
# # 内辺の長D＝5.3のまとめ

# %%
fig = plt.figure(figsize=(15,15)) 
fp = matplotlib.font_manager.FontProperties("Yu Mincho",size=30)
plt.suptitle('内辺の長D=5.3mの比較', fontproperties = fp,y=1,weight="bold")

plt.subplot(221)
plot_53_02H()
plt.subplot(222)
plot_53_04H()
plt.subplot(223)
plot_53_06H()
plt.subplot(224)
plot_53_08H()
plt.subplots_adjust(hspace=0.4)

save_figure(folder_name,'D5.3_compare.png')
plt.show()

# %% [markdown]
# # 内辺の長D＝7.0のまとめ

# %%
fig = plt.figure(figsize=(15,15)) 
fp = matplotlib.font_manager.FontProperties("Yu Mincho",size=30)
plt.suptitle('内辺長D=7mの比較', fontproperties = fp,y=1)
plt.subplot(221)
plot_7_02H()
plt.subplot(222)
plot_7_04H()
plt.subplots_adjust(hspace=0.4)
plt.subplot(223)
plot_7_06H()
plt.subplot(224)
plot_7_08H()
save_figure(folder_name,"D7_compare.png")

# %% [markdown]
# # 内辺の長D＝7.9のまとめ

# %%
fig = plt.figure(figsize=(15,15)) 
fp = matplotlib.font_manager.FontProperties("Yu Mincho",size=30)
plt.suptitle('内辺長D=7.9mの比較', fontproperties = fp,y=1)
plt.subplot(221)
plot_79_02H()
plt.subplot(222)
plot_79_04H()
plt.subplots_adjust(hspace=0.4)
plt.subplot(223)
plot_79_06H()
plt.subplot(224)
plot_79_08H()
save_figure(folder_name,"D7.9_compare.png")

# %% [markdown]
# # D7.0とD5.3の比較
# ## 初期貯鉱量0.4Hの場合

# %%
plt.figure(figsize=(15,15)) 

plt.subplot(221)
plot_53_04H()
plt.subplot(222)
plot_7_04H()
save_figure(folder_name,"D5.3_D7.0_compare.png")

# %% [markdown]
# ## 円形鉛直立坑の計算結果

# %%
# 基本情報設定
folder_name2 = "矩形立坑計算"

def plot_6_02H():
    plot_hang_up_figure(folder_name2,"D6-0.2H Rectangle.csv",6,0.2,3.5e4)
def plot_6_04H():
    plot_hang_up_figure(folder_name2,"D6-0.4H Rectangle.csv",6,0.4)
def plot_6_06H():
    plot_hang_up_figure(folder_name2,"D6-0.6H Rectangle.csv",6,0.6)
def plot_6_08H():
    plot_hang_up_figure(folder_name2,"D6-0.8H Rectangle.csv",6,0.8)
    
def plot_8_02H():
    plot_hang_up_figure(folder_name2,"D8-0.2H Rectangle.csv",8,0.2)
def plot_8_04H():
    plot_hang_up_figure(folder_name2,"D8-0.4H Rectangle.csv",8,0.4)
def plot_8_06H():
    plot_hang_up_figure(folder_name2,"D8-0.6H Rectangle.csv",8,0.6)
def plot_8_08H():
    plot_hang_up_figure(folder_name2,"D8-0.8H Rectangle.csv",8,0.8)
    
    
def plot_9_02H():
    plot_hang_up_figure(folder_name2,"D9-0.2H Rectangle.csv",9,0.2,7.0e4)
def plot_9_04H():
    plot_hang_up_figure(folder_name2,"D9-0.4H Rectangle.csv",9,0.4,6.93e4)
def plot_9_06H():
    plot_hang_up_figure(folder_name2,"D9-0.6H Rectangle.csv",9,0.6)
def plot_9_08H():
    plot_hang_up_figure(folder_name2,"D9-0.8H Rectangle.csv",9,0.8)
    
def plot_10_02H():
    plot_hang_up_figure(folder_name2,"D10-0.2H Rectangle.csv",10,0.2)
def plot_10_04H():
    plot_hang_up_figure(folder_name2,"D10-0.4H Rectangle.csv",10,0.4)
def plot_10_06H():
    plot_hang_up_figure(folder_name2,"D10-0.6H Rectangle.csv",10,0.6)
def plot_10_08H():
    plot_hang_up_figure(folder_name2,"D10-0.8H Rectangle.csv",10,0.8)
    
def plot_big_ball():
    plot_hang_up_figure(folder_name2,"big_ball_D8.csv",8,1.0,"off")

# %% [markdown]
# # 直径$D=6m$のまとめ

# %%
plt.figure(figsize=(15,15))
#plt.suptitle('The Compare Of Well $D=6m$', fontsize=40,y=1)

plt.subplot(221)
plot_6_04H()
plt.subplot(222)
plot_8_04H()


plt.subplots_adjust(hspace=0.5)

save_figure(folder_name2,"D6_compare.png")

# %%
plt.figure(figsize=(15,25))
plt.suptitle('The Compare Of Well $D=6m$', fontsize=40,y=1)

plt.subplot(421)
plot_6_04H()
plt.subplot(422)
plot_53_04H()
plt.subplot(423)
plot_8_04H()
plt.subplot(424)
plot_7_04H()
plt.subplot(425)
plot_9_04H()
plt.subplot(426)
plot_79_04H()


plt.subplots_adjust(hspace=0.5)

save_figure(folder_name,"D6_compare.png")

# %%
plt.figure(figsize=(15,25))
plt.suptitle('The Compare Of Well $D=6m$', fontsize=40,y=1)

plt.subplot(421)
plot_6_04H()
plt.subplot(422)
plot_53_04H()
plt.subplot(423)
plot_8_04H()
plt.subplot(424)
plot_7_04H()
plt.subplot(425)
plot_9_04H()
plt.subplot(426)
plot_79_04H()


plt.subplots_adjust(hspace=0.5)

save_figure(folder_name,"D6_compare.png")
